# %%
import pandas as pd
import numpy as np

# %%
#Load in raw excel data
EXP = pd.read_excel(r'MasterNuclei.xlsx', sheet_name = 'Exp') #experimental

ME2 = pd.read_excel (r'MasterNuclei.xlsx', sheet_name = 'DD-ME2_even-even_nuclei')
MEdelta = pd.read_excel (r'MasterNuclei.xlsx', sheet_name = 'DD-MEdelta_even-even_nuclei')
PC1 = pd.read_excel (r'MasterNuclei.xlsx', sheet_name = 'DD-PC1_even-even_nuclei')
NL3S = pd.read_excel (r'MasterNuclei.xlsx', sheet_name = 'NL3S_even-even_nuclei')


SKMS = pd.read_excel (r'MasterNuclei.xlsx', sheet_name = 'SKMS_all_nuclei')
SKP = pd.read_excel (r'MasterNuclei.xlsx', sheet_name = 'SKP_all_nuclei')
SLY4 = pd.read_excel (r'MasterNuclei.xlsx', sheet_name = 'SLY4_all_nuclei')
SV = pd.read_excel (r'MasterNuclei.xlsx', sheet_name = 'SV-MIN_all_nuclei')
UNEDF0 = pd.read_excel (r'MasterNuclei.xlsx', sheet_name = 'UNEDF0_all_nuclei')
UNEDF1 = pd.read_excel (r'MasterNuclei.xlsx', sheet_name = 'UNEDF1_all_nuclei')

SKMS_even = pd.read_excel (r'All_Even-Even_Nuclei.xlsx', sheet_name = 'SKMS_even-even_nuclei')
SKP_even = pd.read_excel (r'All_Even-Even_Nuclei.xlsx', sheet_name = 'SKP_even-even_nuclei')
SLY4_even = pd.read_excel (r'All_Even-Even_Nuclei.xlsx', sheet_name = 'SLY4_even-even_nuclei')
SV_even = pd.read_excel (r'All_Even-Even_Nuclei.xlsx', sheet_name = 'SV-MIN_even-even_nuclei')
UNEDF0_even = pd.read_excel (r'All_Even-Even_Nuclei.xlsx', sheet_name = 'UNEDF0_even-even_nuclei')
UNEDF1_even = pd.read_excel (r'All_Even-Even_Nuclei.xlsx', sheet_name = 'UNEDF1_even-even_nuclei')


#raw = tuple([EXP, ME2, MEdelta, PC1, NL3S, SKMS, SKP, SLY4, SV, UNEDF0, UNEDF1])

# %%
def BE(Z,N,W,df):
    try:
        return float(df[(df['Z']==Z) & (df['N']==N) & (df['Wigner']==W)]['BE'])
    except:
        return None

def OneNSE(Z,N,W,df):
    try:
        return BE(Z,N,W,df) - BE(Z,N-1,W,df)
    except:
        return None
    
def OnePSE(Z,N,W,df):
    try:
        return BE(Z,N,W,df) - BE(Z-1,N,W,df)
    except:
        return None

def TwoNSE(Z,N,W,df):
    try:
        return BE(Z,N,W,df) - BE(Z,N-2,W,df)
    except:
        return None

def TwoPSE(Z,N,W,df):
    try:
        return BE(Z,N,W,df) - BE(Z-2,N,W,df)
    except:
        return None

def AlphaSE(Z,N,W,df):
    try:
        return BE(Z,N,W,df) - BE(Z-2,N-2,W,df) - 28.3
    except:
        return None

def TwoPSGap(Z,N,W,df):
    try:
        return TwoPSE(Z,N,W,df) - TwoPSE(Z+2,N,W,df)
    except:
        return None

def TwoNSGap(Z,N,W,df):
    try:
        return TwoNSE(Z,N,W,df) - TwoNSE(Z,N+2,W,df)
    except:
        return None

def DoubleMDiff(Z,N,W,df):
    try:
        return (TwoPSE(Z,N,W,df) - TwoPSE(Z,N-2,W,df))/4
    except:
        return None

def N3PointOED(Z,N,W,df):
    try:
        return (-1)**N*(OneNSE(Z,N,W,df) - OneNSE(Z,N+1,W,df))/2
    except:
        return None

def P3PointOED(Z,N,W,df):
    try:
        return (-1)**Z*(OnePSE(Z,N,W,df) - OnePSE(Z+1,N,W,df))/2
    except:
        return None

def SNESplitting(Z,N,W,df):
    try:
        return (-1)**N*(OneNSE(Z,N,W,df) - OneNSE(Z,N+2,W,df))
    except:
        return None

def SPESplitting(Z,N,W,df):
    try:
        return (-1)**Z*(OnePSE(Z,N,W,df) - OnePSE(Z+2,N,W,df))
    except:
        return None

def WignerEC(Z,N,W,df):
    if Z!=N:
        return None
    try:
        return DoubleMDiff(Z,N,W,df)-(DoubleMDiff(Z-2,N,W,df) + DoubleMDiff(Z,N+2,W,df))/2
    except:
        return None
    
def BEperA(Z,N,W,df):
    try:
        return BE(Z,N,W,df)/(Z+N)
    except:
        return None

# %%
def uBE(Z,N,W,df):
    try:
        return float(df[(df['Z']==Z) & (df['N']==N) & (df['Wigner']==W)]['uBE'])
    except:
        return None

def uOneNSE(Z,N,W,df):
    try:
        return uBE(Z,N,W,df) + uBE(Z,N-1,W,df)
    except:
        return None
    
def uOnePSE(Z,N,W,df):
    try:
        return uBE(Z,N,W,df) + uBE(Z-1,N,W,df)
    except:
        return None

def uTwoNSE(Z,N,W,df):
    try:
        return uBE(Z,N,W,df) + uBE(Z,N-2,W,df)
    except:
        return None

def uTwoPSE(Z,N,W,df):
    try:
        return uBE(Z,N,W,df) + uBE(Z-2,N,W,df)
    except:
        return None

def uAlphaSE(Z,N,W,df):
    try:
        return uBE(Z,N,W,df) + uBE(Z-2,N-2,W,df)
    except:
        return None

def uTwoPSGap(Z,N,W,df):
    try:
        return uTwoPSE(Z,N,W,df) + uTwoPSE(Z+2,N,W,df)
    except:
        return None

def uTwoNSGap(Z,N,W,df):
    try:
        return uTwoNSE(Z,N,W,df) + uTwoNSE(Z,N+2,W,df)
    except:
        return None

def uDoubleMDiff(Z,N,W,df):
    try:
        return (uTwoPSE(Z,N,W,df) + uTwoPSE(Z,N-2,W,df))/4
    except:
        return None

def uN3PointOED(Z,N,W,df):
    try:
        return (uOneNSE(Z,N,W,df) + uOneNSE(Z,N+1,W,df))/2
    except:
        return None

def uP3PointOED(Z,N,W,df):
    try:
        return (uOnePSE(Z,N,W,df) + uOnePSE(Z+1,N,W,df))/2
    except:
        return None

def uSNESplitting(Z,N,W,df):
    try:
        return (uOneNSE(Z,N,W,df) + uOneNSE(Z,N+2,W,df))
    except:
        return None

def uSPESplitting(Z,N,W,df):
    try:
        return (uOnePSE(Z,N,W,df) + uOnePSE(Z+2,N,W,df))
    except:
        return None

def uWignerEC(Z,N,W,df):
    if Z!=N:
        return None
    try:
        return uDoubleMDiff(Z,N,W,df)+(uDoubleMDiff(Z-2,N,W,df) + uDoubleMDiff(Z,N+2,W,df))/2
    except:
        return None
    
def uBEperA(Z,N,W,df):
    try:
        return uBE(Z,N,W,df)/(Z+N)
    except:
        return None

# %%
def Wig1(Z, N):
    return (1.8*np.exp(-380*((N-Z)/(N+Z))**2))-(.84*abs(N-Z)*np.exp(-(((N+Z)/26)**2)))

def Wig2(Z, N):
    return -47*(abs(N-Z)/(N+Z))

# %%
#Collect all raw exp data into each individual df

covar = [ME2, MEdelta, PC1, NL3S]

skm = [SKMS, SKP, SLY4, SV, UNEDF0, UNEDF1]
skm_even = [SKMS_even, SKP_even, SLY4_even, SV_even, UNEDF0_even, UNEDF1_even]
skm_merged = []
for i in range(len(skm)):
    skm_merged.append(skm[i].combine_first(skm_even[i]))

raw = [EXP]

for c in covar:
    raw.append(c)
for s in skm_merged:
    raw.append(s)

# %%
filtered = []
for i, d in enumerate(raw):
    if i == 0:
        df = d.loc[:,['Z', 'N', 'Binding_Energy_(MeV)', 'Estimated', 'Uncertainty']]
    else:
        df = d.loc[:,['Z', 'N', 'Binding_Energy_(MeV)']]
        df['Binding_Energy_(MeV)'] = df['Binding_Energy_(MeV)'] * -1
    filtered.append(df)
filtered[0]
# Out:
#         Z    N  Binding_Energy_(MeV)  Estimated  Uncertainty
# 0       3    0         -6.801000e+03       True    2001.0000
# 1       4    1          9.000000e+01       True    2005.0000
# 2       5    1         -2.802000e+03       True    2004.0000
# 3       1    6          6.580000e+03       True    1001.0000
# 4       9    4          5.586100e+04       True     494.0000
# ...   ...  ...                   ...        ...          ...
# 3553  107  155          1.916722e+06      False      93.0624
# 3554  108  158          1.941337e+06      False      27.1054
# 3555  110  159          1.950292e+06      False      31.3923
# 3556    0    1          0.000000e+00      False       0.0000
# 3557    1    0          0.000000e+00      False       0.0000
#
# [3558 rows x 5 columns]

# %%
def Identity(Z, N):
    return 0
wigs = [Identity, Wig1, Wig2]
wigner_dfs =[]
for i, df in enumerate(filtered):
    if i == 0:
        new_df = pd.DataFrame(columns=['Z', 'N', 'Wigner', 'BE', 'Estimated', 'uBE'])
        for wig in range(3):
            for rowi in range(len(df.index)):
                newBE = df.loc[rowi, 'Binding_Energy_(MeV)'] - wigs[wig](df.iloc[rowi,0], df.iloc[rowi,1])
                new_df.loc[len(new_df.index)] = [df.loc[rowi,'Z'], df.loc[rowi,'N'], wig, newBE, df.loc[rowi,'Estimated'], df.loc[rowi,'Uncertainty']]
    else:
        new_df = pd.DataFrame(columns=['Z', 'N', 'Wigner', 'BE'])
        for wig in range(3):
            for rowi in range(len(df.index)):
                newBE = df.loc[rowi, 'Binding_Energy_(MeV)'] - wigs[wig](df.iloc[rowi,0], df.iloc[rowi,1])
                new_df.loc[len(new_df.index)] = [df.loc[rowi,'Z'], df.loc[rowi,'N'], wig, newBE]
    wigner_dfs.append(new_df)
wigner_dfs[0]
# Out:
#          Z    N  Wigner            BE  Estimated  Uncertainty
# 0        3    0       0 -6.801000e+03       True    2001.0000
# 1        4    1       0  9.000000e+01       True    2005.0000
# 2        5    1       0 -2.802000e+03       True    2004.0000
# 3        1    6       0  6.580000e+03       True    1001.0000
# 4        9    4       0  5.586100e+04       True     494.0000
# ...    ...  ...     ...           ...        ...          ...
# 10669  107  155       2  1.916731e+06      False      93.0624
# 10670  108  158       2  1.941346e+06      False      27.1054
# 10671  110  159       2  1.950300e+06      False      31.3923
# 10672    0    1       2  4.700000e+01      False       0.0000
# 10673    1    0       2  4.700000e+01      False       0.0000
#
# [10674 rows x 6 columns]

# %%
mnames = ['EXP', 'ME2', 'MEdelta', 'PC1', 'NL3S', 'SKMS', 'SKP', 'SLY4', 'SV', 'UNEDF0', 'UNEDF1']
qfuncs = [OneNSE, OnePSE, TwoNSE, TwoPSE, AlphaSE, TwoNSGap, TwoPSGap, DoubleMDiff, N3PointOED, P3PointOED, 
          SNESplitting, SPESplitting, WignerEC, BEperA, uOneNSE, uOnePSE, uTwoNSE, uTwoPSE, uAlphaSE, uTwoNSGap, 
          uTwoPSGap, uDoubleMDiff, uN3PointOED, uP3PointOED, uSNESplitting, uSPESplitting, uWignerEC, uBEperA]
qnames = ['OneNSE', 'OnePSE', 'TwoNSE', 'TwoPSE', 'AlphaSE', 'TwoNSGap', 'TwoPSGap', 'DoubleMDiff', 'N3PointOED', 
          'P3PointOED', 'SNESplitting', 'SPESplitting', 'WignerEC', 'BE/A', 'uOneNSE', 'uOnePSE', 'uTwoNSE', 
          'uTwoPSE', 'uAlphaSE', 'uTwoNSGap', 'uTwoPSGap', 'uDoubleMDiff', 'uN3PointOED', 
          'uP3PointOED', 'uSNESplitting', 'uSPESplitting', 'uWignerEC', 'uBE/A']

quan_dfs = []
for m, model in enumerate(wigner_dfs):
    if m == 1:
        qfuncs = qfuncs[:14]
        qnames = qnames[:14]
    print('checkpoint')
    df = pd.DataFrame(columns=qnames)
    for rowi in range(len(model.index)):
        df.loc[len(df.index)] = [q(model.loc[rowi, 'Z'], model.loc[rowi, 'N'], model.loc[rowi, 'Wigner'], model) for q in qfuncs]
    quan_dfs.append(df)
quan_dfs[0]
# Out:
# checkpoint
# checkpoint
# checkpoint
# checkpoint
# checkpoint
# checkpoint
# checkpoint
# checkpoint
# checkpoint
# checkpoint
# checkpoint
#             OneNSE       OnePSE        TwoNSE       TwoPSE       AlphaSE  \
# 0              NaN          NaN           NaN -6801.000000           NaN
# 1              NaN -4525.041200           NaN -7628.041320           NaN
# 2              NaN -2892.000000           NaN -7417.041200           NaN
# 3       810.163000          NaN   -101.796000          NaN           NaN
# 4              NaN -2722.706000           NaN -3081.425300           NaN
# ...            ...          ...           ...          ...           ...
# 10669  6898.749985  1041.628132  15082.367502  3901.644425  17947.721301
# 10670  7832.035620  2597.241903  14566.424932  4105.029611  17921.534521
# 10671  6755.865328  1663.514582  15076.009830  2526.305710  16757.731672
# 10672          NaN          NaN           NaN          NaN           NaN
# 10673          NaN          NaN           NaN          NaN           NaN
#
#          TwoNSGap     TwoPSGap  DoubleMDiff  N3PointOED   P3PointOED  ...  \
# 0             NaN          NaN          NaN         NaN          NaN  ...
# 1             NaN          NaN          NaN         NaN  -816.520600  ...
# 2             NaN          NaN          NaN         NaN          NaN  ...
# 3             NaN          NaN          NaN         NaN          NaN  ...
# 4             NaN          NaN          NaN         NaN          NaN  ...
# ...           ...          ...          ...         ...          ...  ...
# 10669  644.148874          NaN   251.997657  506.661891   410.544110  ...
# 10670  307.592715  1906.898887   180.405005  702.172639  1021.951811  ...
# 10671   75.448050          NaN   204.070967  734.336569          NaN  ...
# 10672         NaN          NaN          NaN         NaN          NaN  ...
# 10673         NaN          NaN          NaN         NaN          NaN  ...
#
#        uAlphaSE  uTwoNSGap  uTwoPSGap  uDoubleMDiff  uN3PointOED  uP3PointOED  \
# 0           NaN        NaN        NaN           NaN          NaN          NaN
# 1           NaN        NaN        NaN           NaN          NaN   3113.06600
# 2           NaN        NaN        NaN           NaN          NaN          NaN
# 3           NaN        NaN        NaN           NaN          NaN          NaN
# 4           NaN        NaN        NaN           NaN          NaN          NaN
# ...         ...        ...        ...           ...          ...          ...
# 10669  184.9104   710.1248        NaN    111.227600    314.46385    233.81485
# 10670   49.2706   351.0924   586.2108     85.538050     39.08340    426.60540
# 10671   55.3483   329.7846        NaN     80.587075    185.03480          NaN
# 10672       NaN        NaN        NaN           NaN          NaN          NaN
# 10673       NaN        NaN        NaN           NaN          NaN          NaN
#
#        uSNESplitting  uSPESplitting  uWignerEC     uBE/A
# 0                NaN            NaN        NaN  667.0000
# 1                NaN            NaN        NaN  401.0000
# 2                NaN            NaN        NaN  334.0000
# 3                NaN            NaN        NaN  143.0000
# 4                NaN            NaN        NaN   38.0000
# ...              ...            ...        ...       ...
# 10669       799.8653            NaN        NaN    0.3552
# 10670       319.0614      1094.1054        NaN    0.1019
# 10671       338.6773            NaN        NaN    0.1167
# 10672            NaN            NaN        NaN    0.0000
# 10673            NaN            NaN        NaN    0.0000
#
# [10674 rows x 28 columns]

# %%
final_dfs = [pd.concat([wigner_dfs[i], quan_dfs[i]], axis=1) for i in range(len(wigner_dfs))]

# %%
final_dfs[0]
# Out:
#          Z    N  Wigner            BE  Estimated  Uncertainty       OneNSE  \
# 0        3    0       0 -6.801000e+03       True    2001.0000          NaN
# 1        4    1       0  9.000000e+01       True    2005.0000          NaN
# 2        5    1       0 -2.802000e+03       True    2004.0000          NaN
# 3        1    6       0  6.580000e+03       True    1001.0000   810.163000
# 4        9    4       0  5.586100e+04       True     494.0000          NaN
# ...    ...  ...     ...           ...        ...          ...          ...
# 10669  107  155       2  1.916731e+06      False      93.0624  6898.749985
# 10670  108  158       2  1.941346e+06      False      27.1054  7832.035620
# 10671  110  159       2  1.950300e+06      False      31.3923  6755.865328
# 10672    0    1       2  4.700000e+01      False       0.0000          NaN
# 10673    1    0       2  4.700000e+01      False       0.0000          NaN
#
#             OnePSE        TwoNSE       TwoPSE  ...  uAlphaSE  uTwoNSGap  \
# 0              NaN           NaN -6801.000000  ...       NaN        NaN
# 1     -4525.041200           NaN -7628.041320  ...       NaN        NaN
# 2     -2892.000000           NaN -7417.041200  ...       NaN        NaN
# 3              NaN   -101.796000          NaN  ...       NaN        NaN
# 4     -2722.706000           NaN -3081.425300  ...       NaN        NaN
# ...            ...           ...          ...  ...       ...        ...
# 10669  1041.628132  15082.367502  3901.644425  ...  184.9104   710.1248
# 10670  2597.241903  14566.424932  4105.029611  ...   49.2706   351.0924
# 10671  1663.514582  15076.009830  2526.305710  ...   55.3483   329.7846
# 10672          NaN           NaN          NaN  ...       NaN        NaN
# 10673          NaN           NaN          NaN  ...       NaN        NaN
#
#        uTwoPSGap  uDoubleMDiff  uN3PointOED  uP3PointOED  uSNESplitting  \
# 0            NaN           NaN          NaN          NaN            NaN
# 1            NaN           NaN          NaN   3113.06600            NaN
# 2            NaN           NaN          NaN          NaN            NaN
# 3            NaN           NaN          NaN          NaN            NaN
# 4            NaN           NaN          NaN          NaN            NaN
# ...          ...           ...          ...          ...            ...
# 10669        NaN    111.227600    314.46385    233.81485       799.8653
# 10670   586.2108     85.538050     39.08340    426.60540       319.0614
# 10671        NaN     80.587075    185.03480          NaN       338.6773
# 10672        NaN           NaN          NaN          NaN            NaN
# 10673        NaN           NaN          NaN          NaN            NaN
#
#        uSPESplitting  uWignerEC     uBE/A
# 0                NaN        NaN  667.0000
# 1                NaN        NaN  401.0000
# 2                NaN        NaN  334.0000
# 3                NaN        NaN  143.0000
# 4                NaN        NaN   38.0000
# ...              ...        ...       ...
# 10669            NaN        NaN    0.3552
# 10670      1094.1054        NaN    0.1019
# 10671            NaN        NaN    0.1167
# 10672            NaN        NaN    0.0000
# 10673            NaN        NaN    0.0000
#
# [10674 rows x 34 columns]

# %%
for i in range(len(final_dfs)):
    final_dfs[i].to_hdf('June2.h5', mnames[i])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_32411/3803399413.py in <module>
#       1 for i in range(len(final_dfs)):
# ----> 2     final_dfs[i].to_hdf('./data/June2.h5', mnames[i])
#
# ~/anaconda3/envs/bmex/lib/python3.9/site-packages/pandas/core/generic.py in to_hdf(self, path_or_buf, key, mode, complevel, complib, append, format, index, min_itemsize, nan_rep, dropna, data_columns, errors, encoding)
#    2761         # Argument 3 to "to_hdf" has incompatible type "NDFrame"; expected
#    2762         # "Union[DataFrame, Series]" [arg-type]
# -> 2763         pytables.to_hdf(
#    2764             path_or_buf,
#    2765             key,
#
# ~/anaconda3/envs/bmex/lib/python3.9/site-packages/pandas/io/pytables.py in to_hdf(path_or_buf, key, value, mode, complevel, complib, append, format, index, min_itemsize, nan_rep, dropna, data_columns, errors, encoding)
#     309     path_or_buf = stringify_path(path_or_buf)
#     310     if isinstance(path_or_buf, str):
# --> 311         with HDFStore(
#     312             path_or_buf, mode=mode, complevel=complevel, complib=complib
#     313         ) as store:
#
# ~/anaconda3/envs/bmex/lib/python3.9/site-packages/pandas/io/pytables.py in __init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     589         self._fletcher32 = fletcher32
#     590         self._filters = None
# --> 591         self.open(mode=mode, **kwargs)
#     592
#     593     def __fspath__(self):
#
# ~/anaconda3/envs/bmex/lib/python3.9/site-packages/pandas/io/pytables.py in open(self, mode, **kwargs)
#     738             raise ValueError(msg)
#     739
# --> 740         self._handle = tables.open_file(self._path, self._mode, **kwargs)
#     741
#     742     def close(self):
#
# ~/anaconda3/envs/bmex/lib/python3.9/site-packages/tables/file.py in open_file(filename, mode, title, root_uep, filters, **kwargs)
#     313
#     314     # Finally, create the File instance, and return it
# --> 315     return File(filename, mode, title, root_uep, filters, **kwargs)
#     316
#     317
#
# ~/anaconda3/envs/bmex/lib/python3.9/site-packages/tables/file.py in __init__(self, filename, mode, title, root_uep, filters, **kwargs)
#     776
#     777         # Now, it is time to initialize the File extension
# --> 778         self._g_new(filename, mode, **params)
#     779
#     780         # Check filters and set PyTables format version for new files.
#
# tables/hdf5extension.pyx in tables.hdf5extension.File._g_new()
#
# ~/anaconda3/envs/bmex/lib/python3.9/site-packages/tables/utils.py in check_file_access(filename, mode)
#     180             check_file_access(filename, 'r+')
#     181         else:
# --> 182             check_file_access(filename, 'w')
#     183     elif mode == 'r+':
#     184         check_file_access(filename, 'r')
#
# ~/anaconda3/envs/bmex/lib/python3.9/site-packages/tables/utils.py in check_file_access(filename, mode)
#     170                 parentname = '.'
#     171             if not os.access(parentname, os.F_OK):
# --> 172                 raise IOError("``%s`` does not exist" % (parentname,))
#     173             if not os.path.isdir(parentname):
#     174                 raise IOError("``%s`` is not a directory" % (parentname,))
#
# OSError: ``./data`` does not exist

# %% [markdown]
# # Adding Uncertainities to EXP

# %%
qfuncs = [uOneNSE, uOnePSE, uTwoNSE, uTwoPSE, uAlphaSE, uTwoNSGap, uTwoPSGap, uDoubleMDiff, 
          uN3PointOED, uP3PointOED, uSNESplitting, uSPESplitting, uWignerEC, uBEperA]
qnames = ['uOneNSE', 'uOnePSE', 'uTwoNSE', 'uTwoPSE', 'uAlphaSE', 'uTwoNSGap', 'uTwoPSGap', 'uDoubleMDiff', 
          'uN3PointOED', 'uP3PointOED', 'uSNESplitting', 'uSPESplitting', 'uWignerEC', 'uBE/A']
uncer_df = pd.DataFrame(columns=qnames)
model = pd.read_hdf('May23.h5', 'EXP')
sorted = pd.DataFrame(columns=['Uncertainty', 'Estimated'])
unsorted = EXP.loc[:,['Uncertainty', 'Estimated']]
for rowi in range(len(model.index)):
    Z, N, W = model.loc[rowi, 'Z'], model.loc[rowi, 'N'], model.loc[rowi, 'Wigner']
    unsorted_row = unsorted[(unsorted['Z'] == Z) & (unsorted['N'] == N) & (unsorted['Wigner'] == W)]
    sorted.loc[len(sorted.index)] = [unsorted_row.loc['Uncertainty'], unsorted_row.loc[rowi, 'Estimated']]
model = pd.concat([model, sorted], axis=1)
for rowi in range(len(model.index)):
    uncer_df.loc[len(uncer_df.index)] = [q(model.loc[rowi, 'Z'], model.loc[rowi, 'N'], model.loc[rowi, 'Wigner'], model) for q in qfuncs]
final_exp = pd.concat([model, uncer_df], axis=1)

# %%
uncer_df = pd.DataFrame(columns=qnames)
model = pd.read_hdf('May23.h5', 'EXP')
sorted = pd.DataFrame(columns=['Uncertainty', 'Estimated'])
unsorted = EXP
for rowi in range(len(model.index)):
    Z, N, W = model.loc[rowi, 'Z'], model.loc[rowi, 'N'], model.loc[rowi, 'Wigner']
    unsorted_row = unsorted[(unsorted['Z'] == Z) & (unsorted['N'] == N) & (unsorted['Wigner'] == W)]
    sorted.loc[len(sorted.index)] = [unsorted_row.loc['Uncertainty'], unsorted_row.loc[rowi, 'Estimated']]
model = pd.concat([model, sorted], axis=1)
model
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/bmex/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/anaconda3/envs/bmex/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/envs/bmex/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Wigner'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_32411/4002273225.py in <module>
#       5 for rowi in range(len(model.index)):
#       6     Z, N, W = model.loc[rowi, 'Z'], model.loc[rowi, 'N'], model.loc[rowi, 'Wigner']
# ----> 7     unsorted_row = unsorted[(unsorted['Z'] == Z) & (unsorted['N'] == N) & (unsorted['Wigner'] == W)]
#       8     sorted.loc[len(sorted.index)] = [unsorted_row.loc['Uncertainty'], unsorted_row.loc[rowi, 'Estimated']]
#       9 model = pd.concat([model, sorted], axis=1)
#
# ~/anaconda3/envs/bmex/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/anaconda3/envs/bmex/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Wigner'

# %%
final_exp.loc[:,['Z','N','Estimated','Uncertainty']]
# Out:
#           Z      N Estimated  Uncertainty
# 0       0.0    1.0      True       2001.0
# 1       1.0    0.0      True       2005.0
# 2       1.0    1.0      True       2004.0
# 3       1.0    2.0      True       1001.0
# 4       2.0    1.0      True        494.0
# ...     ...    ...       ...          ...
# 7645  108.0  157.0       NaN          NaN
# 7646  108.0  158.0       NaN          NaN
# 7647  109.0  157.0       NaN          NaN
# 7648  110.0  159.0       NaN          NaN
# 7649  110.0  160.0       NaN          NaN
#
# [7650 rows x 4 columns]

# %%
final_exp.to_hdf('May23.h5', 'EXP')

# %%
import pandas as pd
x = pd.read_hdf('June2.h5', 'EXP')
for c in x.columns:
    if c not in ['Z', 'N', 'Wigner', 'Estimated']:
        for r in range(len(x.index)):
            x.loc[r,c] = x.loc[r,c]/1000
x
# Out:
#          Z    N  Wigner           BE  Estimated       uBE    OneNSE    OnePSE  \
# 0        3    0       0    -6.801000       True  2.001000       NaN       NaN
# 1        4    1       0     0.090000       True  2.005000       NaN -4.525041
# 2        5    1       0    -2.802000       True  2.004000       NaN -2.892000
# 3        1    6       0     6.580000       True  1.001000  0.810163       NaN
# 4        9    4       0    55.861000       True  0.494000       NaN -2.722706
# ...    ...  ...     ...          ...        ...       ...       ...       ...
# 10669  107  155       2  1916.730683      False  0.093062  6.898750  1.041628
# 10670  108  158       2  1941.346287      False  0.027105  7.832036  2.597242
# 10671  110  159       2  1950.300283      False  0.031392  6.755865  1.663515
# 10672    0    1       2     0.047000      False  0.000000       NaN       NaN
# 10673    1    0       2     0.047000      False  0.000000       NaN       NaN
#
#           TwoNSE    TwoPSE  ...  uAlphaSE  uTwoNSGap  uTwoPSGap  uDoubleMDiff  \
# 0            NaN -6.801000  ...       NaN        NaN        NaN           NaN
# 1            NaN -7.628041  ...       NaN        NaN        NaN           NaN
# 2            NaN -7.417041  ...       NaN        NaN        NaN           NaN
# 3      -0.101796       NaN  ...       NaN        NaN        NaN           NaN
# 4            NaN -3.081425  ...       NaN        NaN        NaN           NaN
# ...          ...       ...  ...       ...        ...        ...           ...
# 10669  15.082368  3.901644  ...  0.184910   0.710125        NaN      0.111228
# 10670  14.566425  4.105030  ...  0.049271   0.351092   0.586211      0.085538
# 10671  15.076010  2.526306  ...  0.055348   0.329785        NaN      0.080587
# 10672        NaN       NaN  ...       NaN        NaN        NaN           NaN
# 10673        NaN       NaN  ...       NaN        NaN        NaN           NaN
#
#        uN3PointOED  uP3PointOED  uSNESplitting  uSPESplitting  uWignerEC  \
# 0              NaN          NaN            NaN            NaN        NaN
# 1              NaN     3.113066            NaN            NaN        NaN
# 2              NaN          NaN            NaN            NaN        NaN
# 3              NaN          NaN            NaN            NaN        NaN
# 4              NaN          NaN            NaN            NaN        NaN
# ...            ...          ...            ...            ...        ...
# 10669     0.314464     0.233815       0.799865            NaN        NaN
# 10670     0.039083     0.426605       0.319061       1.094105        NaN
# 10671     0.185035          NaN       0.338677            NaN        NaN
# 10672          NaN          NaN            NaN            NaN        NaN
# 10673          NaN          NaN            NaN            NaN        NaN
#
#           uBE/A
# 0      0.667000
# 1      0.401000
# 2      0.334000
# 3      0.143000
# 4      0.038000
# ...         ...
# 10669  0.000355
# 10670  0.000102
# 10671  0.000117
# 10672  0.000000
# 10673  0.000000
#
# [10674 rows x 34 columns]

# %%
x.to_hdf('June2.h5', 'EXP')

# %%
df = pd.read_hdf('June2.h5', 'EXP')
step=2
import numpy as np
import pandas as pd
df = df[df["Wigner"]==0]
df = df[df["N"]%step==0]
df = df[df["Z"]%step==0]
print(df)
arr2d = np.full((int(max(df['Z'])//step+1),int(max(df['N'])//step+1)), None)
for rowi in df.index:
    print('HEY')
    arr2d[int(df.loc[rowi,'Z']//step), int(df.loc[rowi,'N']//step)] = df.loc[rowi,'BE']
arr2d
# Out:
#         Z    N  Wigner           BE  Estimated       uBE     OneNSE  \
# 8      14    8       0   132.968000       True  0.506000        NaN
# 16     16   10       0   169.650000       True  0.598000        NaN
# 19      8   20       0   167.664000       True  0.700000   0.669000
# 24     18   12       0   205.980000       True  0.180000  23.976000
# 28     10   22       0   213.472000       True  0.512000   2.266204
# ...   ...  ...     ...          ...        ...       ...        ...
# 3546   94  152       0  1846.608865      False  0.014981   5.854726
# 3547   96  152       0  1859.188817      False  0.002356   6.211662
# 3548  100  148       0  1851.554385      False  0.008506   7.946385
# 3551  100  152       0  1878.920845      False  0.005216   7.213519
# 3554  108  158       0  1941.337453      False  0.027105   7.831892
#
#          OnePSE     TwoNSE     TwoPSE  ...  uAlphaSE  uTwoNSGap  uTwoPSGap  \
# 8      0.731000        NaN  -1.592504  ...       NaN        NaN        NaN
# 16    -0.200000        NaN  -2.363590  ...  1.104000        NaN        NaN
# 19          NaN  -1.270454        NaN  ...       NaN        NaN        NaN
# 24    -0.761000        NaN  -3.426151  ...  0.778000        NaN        NaN
# 28    27.131000   2.436049        NaN  ...  1.212000   1.787251        NaN
# ...         ...        ...        ...  ...       ...        ...        ...
# 3546   7.638865  10.553907        NaN  ...  0.256981        NaN        NaN
# 3547   6.935817  11.366803  12.579952  ...  0.004698   0.016512   0.021243
# 3548   3.969561  14.436028   6.770373  ...  0.011117   0.038590   0.268538
# 3551   4.983911  13.398220   8.931670  ...  0.010350   0.020187   0.021635
# 3554   2.597453  14.566136   4.105453  ...  0.049271   0.351092   0.586211
#
#       uDoubleMDiff  uN3PointOED  uP3PointOED  uSNESplitting  uSPESplitting  \
# 8              NaN          NaN          NaN            NaN            NaN
# 16             NaN          NaN          NaN            NaN            NaN
# 19             NaN          NaN          NaN            NaN            NaN
# 24             NaN     0.490500     0.436500       0.802770            NaN
# 28             NaN     0.942097     1.000456       1.882194       1.495804
# ...            ...          ...          ...            ...            ...
# 3546           NaN     0.145292     0.137481            NaN       0.262337
# 3547      0.005301     0.005441     0.002978       0.018800       0.005151
# 3548      0.006580     0.135106     0.100433       0.269606       0.442360
# 3551      0.004950     0.013129     0.007864       0.022896       0.020164
# 3554      0.085538     0.039083     0.426605       0.319061       1.094105
#
#       uWignerEC     uBE/A
# 8           NaN  0.023000
# 16          NaN  0.023000
# 19          NaN  0.025000
# 24          NaN  0.006000
# 28          NaN  0.016000
# ...         ...       ...
# 3546        NaN  0.000061
# 3547        NaN  0.000010
# 3548        NaN  0.000034
# 3551        NaN  0.000021
# 3554        NaN  0.000102
#
# [886 rows x 34 columns]
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# HEY
# array([[None, None, None, ..., None, None, None],
#        [None, 28.2956624, 29.271119400000003, ..., None, None, None],
#        [None, 26.9234868, 56.4994848, ..., None, None, None],
#        ...,
#        [None, None, None, ..., 2047.474, 2060.352, 2072.63],
#        [None, None, None, ..., None, 2064.8, 2077.872],
#        [None, None, None, ..., None, None, 2081.226]], dtype=object)

# %%
np.arange(0, 6, 2)
# Out:
# array([0, 2, 4])

# %%
np.full((3,3), None).shape
# Out:
# (3, 3)

# %%
x = np.full((3,3), None)
x[x==None] = 1
x
# Out:
# array([[1, 1, 1],
#        [1, 1, 1],
#        [1, 1, 1]], dtype=object)

# %%
# make a heatmap in plotly
import plotly.graph_objects as go
import numpy as np

# Generate data
z = np.random.randint(0, 255, (2, 4))

# Configure the trace.
trace = go.Heatmap(z=z, hovertemplate = '<b><i>N</i></b>: %{x}<br>'+'<b><i>Z</i></b>: %{y}<br>'+'<b><i>Value</i></b>: %{z}',
                   text=np.array([['A', 'B', 'C', 'D'], ['E', 'F', 'G', 'H']]), texttemplate="%{text}",)

data=[trace]
fig = go.Figure(data=data)
fig.show()
# Out:
# <div>                            <div id="8230d612-8167-461c-8a04-4beff470364d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8230d612-8167-461c-8a04-4beff470364d")) {                    Plotly.newPlot(                        "8230d612-8167-461c-8a04-4beff470364d",                        [{"hovertemplate":"<b><i>N</i></b>: %{x}<br><b><i>Z</i></b>: %{y}<br><b><i>Value</i></b>: %{z}","text":[["A","B","C","D"],["E","F","G","H"]],"z":[[77,235,56,20],[45,192,77,234]],"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scatter ...
#
# var gd = document.getElementById('8230d612-8167-461c-8a04-4beff470364d');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display ||
